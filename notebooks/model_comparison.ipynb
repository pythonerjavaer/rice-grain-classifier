# %% [markdown]
# # Rice Grain Model Comparison
# Compare classical classifiers with a consistent preprocessing and validation protocol.

# %%
from rice_classifier.data import make_demo_data
from rice_classifier.experiment import compare_models

data = make_demo_data()
data.head()

# %%
results, best_model = compare_models(data, model_names=['logistic_regression', 'random_forest'])
{name: result.to_dict() for name, result in results.items()}
